# %%
import pandas as pd

data = {
    '이름':['홍길동','유관순','이순신','강감찬','김구','김유신','홍길자','홍길순'],
    '학교':['가산고','가산고','가산고','가산고','가산고','디지털고','디지털고','디지털고'],
    '키':[197,184,168,187,188,202,188,190],
    '국어':[90,40,80,40,15,80,55,100],
    '영어':[85,35,75,60,20,100,65,85],
    '수학':[100,50,70,70,10,95,45,90],
    '과학':[95,55,80,75,35,85,40,95],
    '사회':[85,25,75,80,10,80,35,95],
    'SW특기':['Python','Java','Javascript','','','C','PYTHON','C#']
}

# %%
df = pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df.index.name = '지원번호'

# %%
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    홍길동   가산고  197   90   85  100  95  85      Python
# 2번    유관순   가산고  184   40   35   50  55  25        Java
# 3번    이순신   가산고  168   80   75   70  80  75  Javascript
# 4번    강감찬   가산고  187   40   60   70  75  80
# 5번     김구   가산고  188   15   20   10  35  10
# 6번    김유신  디지털고  202   80  100   95  85  80           C
# 7번    홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 8번    홍길순  디지털고  190  100   85   90  95  95          C#

# %%
# 파일 저장
df.to_csv('score.csv',encoding='utf-8-sig')     # 엑셀파일에서 한글 깨지지 않게 (csv) >> utf-8-sig

# %%
# 파일 저장 시 index 제외
df.to_csv('score2.csv',encoding='utf-8-sig',index=False)

# %%
# 텍스트파일로 저장
# df.to_csv('score2.txt',encoding='utf-8')
df.to_csv('score2.txt',sep='\t',encoding='utf-8')   # 구분자 '\t' 로 변경

# %%
# 엑셀파일로 저장
# df.to_excel('score.xlsx')
df.to_csv('score2.xlsx',encoding='utf-8')

# %% [markdown]
# 파일 읽어오기 - txt, csv, excel

# %%
# df1 = pd.read_csv('score.csv')
# df1 = pd.read_csv('score.csv',skiprows=[1,3,5])       
# df1 = pd.read_csv('score.csv',skiprows=1)       # 나머지 중 첫 번째 행을 컬럼으로 만듦
df1 = pd.read_csv('score.csv',skiprows=2,nrows=5) # row를 2개 스킵, 나머지 중 5개만 가져오기
df1
# Out:
#    2번  유관순   가산고  184  40   35  50  55  25        Java
# 0  3번  이순신   가산고  168  80   75  70  80  75  Javascript
# 1  4번  강감찬   가산고  187  40   60  70  75  80         NaN
# 2  5번   김구   가산고  188  15   20  10  35  10         NaN
# 3  6번  김유신  디지털고  202  80  100  95  85  80           C
# 4  7번  홍길자  디지털고  188  55   65  45  40  35      PYTHON

# %%
df2 = pd.read_excel('score.xlsx')
df2
# Out:
#   지원번호   이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  홍길동   가산고  197   90   85  100  95  85      Python
# 1   2번  유관순   가산고  184   40   35   50  55  25        Java
# 2   3번  이순신   가산고  168   80   75   70  80  75  Javascript
# 3   4번  강감찬   가산고  187   40   60   70  75  80         NaN
# 4   5번   김구   가산고  188   15   20   10  35  10         NaN
# 5   6번  김유신  디지털고  202   80  100   95  85  80           C
# 6   7번  홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 7   8번  홍길순  디지털고  190  100   85   90  95  95          C#

# %%
df3 = pd.read_csv('score2.txt')
df3
# Out:
#            지원번호\t이름\t학교\t키\t국어\t영어\t수학\t과학\t사회\tSW특기
# 0     1번\t홍길동\t가산고\t197\t90\t85\t100\t95\t85\tPython
# 1        2번\t유관순\t가산고\t184\t40\t35\t50\t55\t25\tJava
# 2  3번\t이순신\t가산고\t168\t80\t75\t70\t80\t75\tJavascript
# 3            4번\t강감찬\t가산고\t187\t40\t60\t70\t75\t80\t
# 4             5번\t김구\t가산고\t188\t15\t20\t10\t35\t10\t
# 5         6번\t김유신\t디지털고\t202\t80\t100\t95\t85\t80\tC
# 6     7번\t홍길자\t디지털고\t188\t55\t65\t45\t40\t35\tPYTHON
# 7        8번\t홍길순\t디지털고\t190\t100\t85\t90\t95\t95\tC#

# %%
# df_p = pd.read_csv('people.csv') # unicode decode error ??
df_p = pd.read_excel('people.xlsx',skiprows=2,nrows=2)
df_p = pd.read_excel('people.xlsx')
df_p
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    ※ 매월 말일자 통계 현황 Unnamed: 1  Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0             NaN        NaN    2025년04월         NaN             NaN
# 1          행정기관코드       행정기관        총인구수         세대수          세대당 인구
# 2      1000000000       전국    51,175,725  24,212,185            2.11
# 3      1100000000    서울특별시     9,331,860   4,498,689            2.07
# 4      2600000000    부산광역시     3,256,408   1,573,173            2.07
# 5      2700000000    대구광역시     2,359,159   1,107,916            2.13
# 6      2800000000    인천광역시     3,033,844   1,385,644            2.19
# ...

# %%
df_pp = pd.read_excel('202401_202406_연령별인구현황_월간.xlsx',skiprows=3,index_col='행정기관')
## index_col= >> set_index()와 동일, 특정 칼럼을 인덱스로 설정

df_pp
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                행정기관코드       총 인구수     연령구간인구수       0~9세     10~19세  \
# 행정기관
# 전국                  0  51,313,912  51,313,912  3,313,117  4,647,643
# 서울특별시      1100000000   9,384,325   9,384,325    510,839    732,095
# 부산광역시      2600000000   3,290,964   3,290,964    193,250    263,391
# 대구광역시      2700000000   2,373,844   2,373,844    149,665    213,887
# 인천광역시      2800000000   3,000,454   3,000,454    201,809    272,177
# 광주광역시      2900000000   1,418,241   1,418,241     98,976    147,261
# 대전광역시      3000000000   1,441,562   1,441,562     96,135    137,554
# 울산광역시      3100000000   1,103,402   1,103,402     78,510    109,492
# 세종특별자치시    3600000000     386,944     386,944     43,401     50,847
# 경기도        4100000000  13,635,250  13,635,250    984,022  1,320,140
# ...

# %%
df_p3 = pd.read_excel('202412_202412_연령별인구현황_연간.xlsx',skiprows=3,index_col='행정기관',nrows=1,usecols='B,E:P')
# nrows : 가져올 row의 수
# usecols : 해당 칼럼을 가져오기 (엑셀 상)
df_p3
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#            0~9세     10~19세     20~29세     30~39세     40~49세     50~59세  \
# 행정기관
# 전국    3,140,118  4,619,265  5,955,656  6,624,563  7,722,823  8,706,370
#
#          60~69세     70~79세     80~89세   90~99세 100세 이상       남 인구수
# 행정기관
# 전국    7,818,783  4,186,597  2,104,544  329,925   8,577  25,498,324
